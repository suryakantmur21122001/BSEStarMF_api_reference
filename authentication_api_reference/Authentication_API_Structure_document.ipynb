# %% [markdown]
# # **BSE Star MF Authentication API**

# %% [markdown]
# ## API Method
# getPassword

# %% [markdown]
# ## Description
#
# This API is used to authenticate the member system with BSE Star MF Web Service.
# After successful authentication, the API returns an encrypted password (Session ID)
# which is used for placing orders.

# %% [markdown]
# ## API Parameters

# %% [markdown]
# ![Capture103.PNG](attachment:e08c65e1-fa68-4ecc-a589-54a4bd69cb11.PNG)

# %% [markdown]
# ## WSDL Definition:-

# %% [markdown]
# ![Capture104.PNG](attachment:2c8744ff-8507-4a79-a9b9-9ec14966bcd4.PNG)

# %% [markdown]
# ## Sample SOAP Request:-

# %% [markdown]
# ![Capture105.PNG](attachment:f1bce74c-0556-4001-8147-0e8bd4a27bc0.PNG)

# %% [markdown]
# ## API Response Parameters:-

# %% [markdown]
# ![Capture106.PNG](attachment:cfc63f39-fa34-410f-b1a2-ec7bf8b8076f.PNG)

# %% [markdown]
# ## WSDL Definition for Reponse:-

# %% [markdown]
# ![Capture107.PNG](attachment:80019356-adee-4058-a847-5d07348e265c.PNG)

# %% [markdown]
# ## Sample SOAP Response:-

# %% [markdown]
# ![Capture108.PNG](attachment:9ce93720-14a7-4054-b0db-5f645bd69cc7.PNG)

# %% [markdown]
# Structure :  Response Code |Encrypted Password (Session ID)
#
# Sample : 100|UWQ/yLAS7KmiHyExtsKKq3DuHTWuyGOzy0P4s38PSL8nA==
